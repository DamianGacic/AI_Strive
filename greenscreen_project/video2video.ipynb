# %%
import numpy as np
import cv2
import os

# %%
count = 0
lower_green = np.array([0,80,0])
upper_green = np.array([120,255,120])

background_image = cv2.imread('motorhome-caravan.jpg')

for pic in os.listdir('CARDS/0C'): 
    #print(pic)
    image = cv2.imread('CARDS/0C/'+pic)
    mask = cv2.inRange(image, lower_green, upper_green)
    masked_image = np.copy(image)
    masked_image[mask != 0] = [0, 0, 0]
    bg_copy = np.copy(background_image)
    resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
    inv_mask = cv2.bitwise_not(mask)
    masked_bg = np.copy(resized)
    masked_bg[inv_mask != 0] = [0, 0, 0]
    new_vid_frame = masked_bg + masked_image
    cv2.imwrite("img5/frame5555%d.jpg" % count, new_vid_frame)
    count += 1

# %%
for group in os.listdir('CARDS'): 
    for pic in os.listdir('CARDS/'+group): 
        #print(pic)
        image = cv2.imread('CARDS/'+group+'/'+pic)
        mask = cv2.inRange(image, lower_green, upper_green)
        masked_image = np.copy(image)
        masked_image[mask != 0] = [0, 0, 0]
        bg_copy = np.copy(background_image)
        resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
        inv_mask = cv2.bitwise_not(mask)
        masked_bg = np.copy(resized)
        masked_bg[inv_mask != 0] = [0, 0, 0]
        new_vid_frame = masked_bg + masked_image
        cv2.imwrite("img6/new%d.jpg" % count, new_vid_frame)
        count += 1

# %%
background_image = cv2.imread('motorhome-caravan.jpg')

# %%
lower_green = np.array([0,80,0])
upper_green = np.array([120,255,120])

# %%
lower_green = np.array([0,80,0])
upper_green = np.array([120,255,120])

for back in os.listdir('backgrounds'):
    background_image = cv2.imread('backgrounds/'+back)
    s = str(back)
    #the one loop to rule them all
    for pic in os.listdir('Cards.v1-first.yolov5pytorch/train/images/'): 
        image = cv2.imread('Cards.v1-first.yolov5pytorch/train/images/'+pic)
        mask = cv2.inRange(image, lower_green, upper_green)
        masked_image = np.copy(image)
        masked_image[mask != 0] = [0, 0, 0]
        bg_copy = np.copy(background_image)
        resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
        inv_mask = cv2.bitwise_not(mask)
        masked_bg = np.copy(resized)
        masked_bg[inv_mask != 0] = [0, 0, 0]
        new_vid_frame = masked_bg + masked_image
        cv2.imwrite("Cards.v1-first.yolov5pytorch/train/labels3/"+s[0]+pic+".jpg", new_vid_frame)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-45201d2c602f> in <module>
#      17         masked_bg[inv_mask != 0] = [0, 0, 0]
#      18         new_vid_frame = masked_bg + masked_image
# ---> 19         cv2.imwrite("Cards.v1-first.yolov5pytorch/train/labels3/"+s[0]+pic+".jpg", new_vid_frame)
#
# KeyboardInterrupt:

# %%
if not os.path.exists('textfolder'):
    os.mkdir('textfolder')
else:
    print('well well well')

# %%
    os.rename('textfolder','schmextfolder')

# %%
if os.path.exists('textfolder'):
    os.rmdir('textfolder')

# %%
#the one loop to rule them all
for pic in os.listdir('Cards.v1-first.yolov5pytorch/train/images/'): 
    print(pic)
    image = cv2.imread('Cards.v1-first.yolov5pytorch/train/images/'+pic)
    mask = cv2.inRange(image, lower_green, upper_green)
    masked_image = np.copy(image)
    masked_image[mask != 0] = [0, 0, 0]
    bg_copy = np.copy(background_image)
    resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
    inv_mask = cv2.bitwise_not(mask)
    masked_bg = np.copy(resized)
    masked_bg[inv_mask != 0] = [0, 0, 0]
    new_vid_frame = masked_bg + masked_image
    cv2.imwrite("Cards.v1-first.yolov5pytorch/train/labels3/"+s[0]+pic+".jpg", new_vid_frame)

# %%
for pic in os.listdir('Cards.v1-first.yolov5pytorch/train/labels/'): 
    print(pic)

# %%
for file in filenames:
    with open('Cards.v1-first.yolov5pytorch/train/labels/'+file) as f:
        with open('Cards.v1-first.yolov5pytorch/train/labels2/'+file, "w") as f1:
            for line in f:
                f1.write(line)

# %%
with open("test.txt") as f:
    with open("testf/test2.txt", "w") as f1:
        for line in f:
            f1.write(line)

# %%
import glob
for pic in glob.glob('Cards.v1-first.yolov5pytorch/train/images/*jpg'): 
    print(pic)

# %%
from glob import glob 
dtd_dir="dtd/images/"
bg_images=[]
for subdir in glob(dtd_dir+"/"):
    for f in glob(subdir+"/.jpg"):
        bg_images.append(mpimg.imread(f))
print("Nb of images loaded :",len(bg_images))
print("Saved in :",backgrounds_pck_fn)
pickle.dump(bg_images,open(backgrounds_pck_fn,'wb'))

# %%
for pic in os.listdir('Cards.v1-first.yolov5pytorch/train/images/'): 
    print(pic)
    image = cv2.imread('Cards.v1-first.yolov5pytorch/train/images/'+pic)
    mask = cv2.inRange(image, lower_green, upper_green)
    masked_image = np.copy(image)
    masked_image[mask != 0] = [0, 0, 0]
    bg_copy = np.copy(background_image)
    resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
    inv_mask = cv2.bitwise_not(mask)
    masked_bg = np.copy(resized)
    masked_bg[inv_mask != 0] = [0, 0, 0]
    new_vid_frame = masked_bg + masked_image
    cv2.imwrite("Cards.v1-first.yolov5pytorch/train/labels3/a"+pic+".jpg", new_vid_frame)

# %%
Cards.v1-first.yolov5pytorch/train
/images/0S1_jpg.rf.7dd27db352decb747371b094887e9721.jpg
/labels/0S1_jpg.rf.7dd27db352decb747371b094887e9721.txt

# %%
cv2.imshow('n',new_vid_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
import numpy as np
import glob
 
img_array = []
for filename in glob.glob('img2/*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)

out = cv2.VideoWriter('newVid.avi',cv2.VideoWriter_fourcc(*'DIVX'), 15, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()

# %%
for file in filenames:
    with open('Cards.v1-first.yolov5pytorch/train/labels/'+file) as f:
        with open('Cards.v1-first.yolov5pytorch/train/labels2/'+file, "w") as f1:
            for line in f:
                f1.write(line)

# %%
img = cv2.imread('Cards.v1-first.yolov5pytorch/train\images/0S1_jpg.rf.7dd27db352decb747371b094887e9721.jpg')
roi1 = img[0.6310096153846154:0.7007211538461539, 0.057692307692307696: 0.0625]

# 0.6310096153846154 0.7007211538461539 0.0625 0.057692307692307696
# 0.4326923076923077 0.35336538461538464 0.06129807692307692 0.057692307692307696
# 0.640625 0.36778846153846156 0.06370192307692307 0.056490384615384616
# 0.42908653846153844 0.6778846153846154 0.05889423076923077 0.055288461538461536
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
import cv2
background_image = cv2.imread('motorhome-caravan.jpg')
lower_green = np.array([0,80,0])
upper_green = np.array([120,255,120])
for pic in os.listdir('Cards.v1-first.yolov5pytorch/train/images/'): 

    image = cv2.imread('Cards.v1-first.yolov5pytorch/train/images/'+pic)
    mask = cv2.inRange(image, lower_green, upper_green)
    masked_image = np.copy(image)
    masked_image[mask != 0] = [0, 0, 0]
    bg_copy = np.copy(background_image)
    resized = cv2.resize(bg_copy, (image.shape[1],image.shape[0]), interpolation = cv2.INTER_AREA)
    inv_mask = cv2.bitwise_not(mask)
    masked_bg = np.copy(resized)
    masked_bg[inv_mask != 0] = [0, 0, 0]
    new_vid_frame = masked_bg + masked_image
    cv2.imwrite("Cards.v1-first.yolov5pytorch/train/roi1/"+pic+".jpg", new_vid_frame)
print(new_vid_frame)
# Out:
# [[[154 137 128]
#   [154 137 128]
#   [154 137 128]
#   ...
#   [176  96   1]
#   [177  97   3]
#   [174  93   2]]
#
#  [[158 141 132]
#   [158 141 132]
#   [157 140 131]
#   ...
#   [177  97   2]
#   [178  98   4]
#   [175  94   3]]
#
#  [[161 144 135]
#   [161 144 135]
#   [160 143 134]
#   ...
#   [175  95   1]
#   [175  95   1]
#   [173  92   1]]
#
#  ...
#
#  [[ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]
#   ...
#   [ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]]
#
#  [[ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]
#   ...
#   [ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]]
#
#  [[ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]
#   ...
#   [ 72  51  50]
#   [ 72  51  50]
#   [ 72  51  50]]]

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

img = cv2.imread('Cards.v1-first.yolov5pytorch/train\images/0S1_jpg.rf.7dd27db352decb747371b094887e9721.jpg')
dh, dw, _ = img.shape

fl = open('Cards.v1-first.yolov5pytorch/train/labels/0S1_jpg.rf.7dd27db352decb747371b094887e9721.txt', 'r')
data = fl.readlines()
fl.close()
roi1 = 's'
roi2 = 's'
roi3 = 's'
roi4 = 's'
for dt in data:

    # Split string to float
    _, x, y, w, h = map(float, dt.split(' '))

    # Taken from https://github.com/pjreddie/darknet/blob/810d7f797bdb2f021dbe65d2524c2ff6b8ab5c8b/src/image.c#L283-L291
    # via https://stackoverflow.com/questions/44544471/how-to-get-the-coordinates-of-the-bounding-box-in-yolo-object-detection#comment102178409_44592380
    l = int((x - w / 2) * dw)
    r = int((x + w / 2) * dw)
    t = int((y - h / 2) * dh)
    b = int((y + h / 2) * dh)
    
    if l < 0:
        l = 0
    if r > dw - 1:
        r = dw - 1
    if t < 0:
        t = 0
    if b > dh - 1:
        b = dh - 1

    if roi1 == 's':
        roi1 = img[t:b,l:r]
    elif roi2 == 's':
        roi2 = img[t:b,l:r]
    elif roi3 == 's':
        roi3 = img[t:b,l:r]
    elif roi4 == 's':
        roi4 = img[t:b,l:r]
    else:
        break
plt.imshow(img)
plt.show()
plt.imshow(roi1)
plt.show()
plt.imshow(roi2)
plt.show()
plt.imshow(roi3)
plt.show()
plt.imshow(roi4)
plt.show()

cv2.imwrite("Cards.v1-first.yolov5pytorch/train/roi1/"+str(roi1)+".jpg", roi1)
cv2.imwrite("Cards.v1-first.yolov5pytorch/train/roi1/"+str(roi2)+".jpg", roi2)
cv2.imwrite("Cards.v1-first.yolov5pytorch/train/roi1/"+str(roi3)+".jpg", roi3)
cv2.imwrite("Cards.v1-first.yolov5pytorch/train/roi1/"+str(roi4)+".jpg", roi4)
# Out:
# <ipython-input-6-1e30fdb5c06f>:37: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if roi1 == 's':
# <ipython-input-6-1e30fdb5c06f>:39: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif roi2 == 's':
# <ipython-input-6-1e30fdb5c06f>:41: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif roi3 == 's':
# False

# %%
(l, r), (t, b)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('Cards.v1-first.yolov5pytorch/train\images/0S1_jpg.rf.7dd27db352decb747371b094887e9721.jpg')
dh, dw, _ = img.shape

fl = open('Cards.v1-first.yolov5pytorch/train/labels/0S1_jpg.rf.7dd27db352decb747371b094887e9721.txt', 'r')
data = fl.readlines()
fl.close()

for dt in data:

    # Split string to float
    _, x, y, w, h = map(float, dt.split(' '))

    # Taken from https://github.com/pjreddie/darknet/blob/810d7f797bdb2f021dbe65d2524c2ff6b8ab5c8b/src/image.c#L283-L291
    # via https://stackoverflow.com/questions/44544471/how-to-get-the-coordinates-of-the-bounding-box-in-yolo-object-detection#comment102178409_44592380
    l = int((x - w / 2) * dw)
    r = int((x + w / 2) * dw)
    t = int((y - h / 2) * dh)
    b = int((y + h / 2) * dh)
    
    if l < 0:
        l = 0
    if r > dw - 1:
        r = dw - 1
    if t < 0:
        t = 0
    if b > dh - 1:
        b = dh - 1

    cv2.rectangle(img, (l, t), (r, b), (0, 0, 255), 1)

plt.imshow(img)
plt.show()
